# %%
# !pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.11.3 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.4 MB/s eta 0:00:00
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://m001-student:3GWBsaDUTOVpn3Ce@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority&appName=Sandbox"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

# %%
# Obtiene la coleccion de mongo
dbname = client['sample_airbnb']
collection_name = dbname['listingsAndReviews']

# filtra los datos, si find({}) obtiene todos los datos sino lo filtra
listingsAndReviews_cursor = collection_name.find({ 'bedrooms': 3})

# Transforma el resultado a un dataframe
listingsAndReviews_df = pd.DataFrame(listingsAndReviews_cursor)
listingsAndReviews_df.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10166883  https://www.airbnb.com/rooms/10166883
# 2  10116578  https://www.airbnb.com/rooms/10116578
# 3  10066928  https://www.airbnb.com/rooms/10066928
# 4  10220130  https://www.airbnb.com/rooms/10220130
#
#                                                name  \
# 0                           Ribeira Charming Duplex
# 1  Large railroad style 3 bedroom apt in Manhattan!
# 2                        Apartamento zona sul do RJ
# 3                    3 chambres au coeur du Plateau
# 4  Cozy aptartment in Recreio (near Olympic Venues)
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  Spacious 3 bedroom apartment. 2 are railroad s...
# 2  próximo aos principais pontos turísticos,,do l...
# 3  Notre appartement comporte 3 chambres avec cha...
# 4  Cozy and comfortable apartment. Ideal for fami...
#
# ...

# %%
import sqlalchemy as db

# %%
# Crear conexion a base de datos mysql
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
# lectura de tabla
departments_df = pd.read_sql_table(table_name='departments', con=conn)

# %%
# Creamos la base de datos y la coleccion departments
dbname_retail = client['retail_db']
collection_name_departments = dbname_retail['departments_2']

# %%
# Transformacion del datafram a un diccionario
df_to_dict = departments_df.to_dict('records')

# Inserta los datos a la coleccion
collection_name_departments.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('67ec9315bda6378e6893acdd'), ObjectId('67ec9315bda6378e6893acde'), ObjectId('67ec9315bda6378e6893acdf'), ObjectId('67ec9315bda6378e6893ace0'), ObjectId('67ec9315bda6378e6893ace1'), ObjectId('67ec9315bda6378e6893ace2')], acknowledged=True)
